# %%
import pandas as pd
import numpy as np
import nltk
# 토크나이져 다운로드
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import TreebankWordTokenizer
import platform 
from matplotlib import font_manager, rc
from matplotlib import pyplot as plt
from nltk.tokenize import sent_tokenize
from kss import split_sentences
import re
nltk.download('stopwords')
from nltk.corpus import stopwords
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hajer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hajer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df1=pd.read_csv("steam_info.csv", header=0, usecols=["appid", "genre"])
df1
# Out:
#          appid                                              genre
# 0      1446780                                             Action
# 1      1172470                    Action, Adventure, Free to Play
# 2       648800                       Adventure, Indie, Simulation
# 3      1880360                                             Action
# 4       578080  Action, Adventure, Free to Play, Massively Mul...
# ...        ...                                                ...
# 63961  1204780                              Action, Casual, Indie
# 63962  1204820                                      Action, Indie
# 63963  1204830                              Action, Casual, Indie
# 63964  1190690                                        Action, RPG
# 63965  1190730                                  RPG, Early Access
#
# [63966 rows x 2 columns]

# %%
df2=pd.read_csv("steam_reaview1.csv", header=0, usecols=["appid", "review"])
df2
# Out:
#          appid                                             review
# 0      1446780  I've been playing for 3 Hours and its already ...
# 1      1446780                  I LOVE KILLING ENDANGERED SPECIES
# 2      1446780  I like to brutally murder animal species for a...
# 3      1446780  You can put cats into submarines to get honey ...
# 4      1446780                                         No handler
# ...        ...                                                ...
# 99995  1174180                    everything about it is amazing.
# 99996  1174180  Played RDR2 on PS4 and loved it. So I bought R...
# 99997  1174180                                       it's alright
# 99998  1174180  I am still exploring the world of this game, i...
# 99999  1174180                                      AMAZING GAMES
#
# [100000 rows x 2 columns]

# %%
df2 = df2.astype({'appid' :'str'})
df2
# Out:
#          appid                                             review
# 0      1446780  I've been playing for 3 Hours and its already ...
# 1      1446780                  I LOVE KILLING ENDANGERED SPECIES
# 2      1446780  I like to brutally murder animal species for a...
# 3      1446780  You can put cats into submarines to get honey ...
# 4      1446780                                         No handler
# ...        ...                                                ...
# 99995  1174180                    everything about it is amazing.
# 99996  1174180  Played RDR2 on PS4 and loved it. So I bought R...
# 99997  1174180                                       it's alright
# 99998  1174180  I am still exploring the world of this game, i...
# 99999  1174180                                      AMAZING GAMES
#
# [100000 rows x 2 columns]

# %%
type(df2['appid'])
# Out:
# pandas.core.series.Series

# %%
for i in range(len(100000):
    df2['appid'][i] = str(df2['appid'][i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10988/3706792368.py in <module>
# ----> 1 for i in len(100000):
#       2     df2['appid'][i] = str(df2['appid'][i])
#
# TypeError: object of type 'int' has no len()

# %%
for appid in tqdm(df2['appid'].unique()):
  df2.loc[df2['appid']==appid, 'review'] = " ".join(df2[df2['appid']==appid]['review'])
df2
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10988/1804590653.py in <module>
#       1 for appid in tqdm(df2['appid'].unique()):
# ----> 2   df2.loc[df2['appid']==appid, 'review'] = " ".join(df2[df2['appid']==appid]['review'])
#       3 df2
#
# TypeError: sequence item 1062: expected str instance, float found

# %%
df3=pd.read_csv("steam_reaview2.csv", header=0, usecols=["appid", "review"])
df3
# Out:
#          appid                                             review
# 0      1446780  I've been playing for 3 Hours and its already ...
# 1      1446780                  I LOVE KILLING ENDANGERED SPECIES
# 2      1446780  I like to brutally murder animal species for a...
# 3      1446780  You can put cats into submarines to get honey ...
# 4      1446780                                         No handler
# ...        ...                                                ...
# 99995  1446780                                          gud gam\n
# 99996  1446780  If you like the Monster Hunter franchise, you ...
# 99997  1446780  In my opinion, the best MH to date.\n\nIt's no...
# 99998  1446780                                               ngam
# 99999  1446780                                        I like cats
#
# [100000 rows x 2 columns]

# %%
df4=pd.read_csv("steam_reaview3.csv", header=0, usecols=["appid", "review"])
df4
# Out:
#          appid                                             review
# 0      1172470                                             guns\n
# 1      1172470   IF SOMEONE NAMED CRAN IS ON YOUR TEAM LEAVE H...
# 2      1172470  getting an account deactivated over a midly of...
# 3      1172470                                                  😊
# 4      1172470                                        good game\n
# ...        ...                                                ...
# 99995  1446780                                          gud gam\n
# 99996  1446780  If you like the Monster Hunter franchise, you ...
# 99997  1446780  In my opinion, the best MH to date.\n\nIt's no...
# 99998  1446780                                               ngam
# 99999  1446780                                        I like cats
#
# [100000 rows x 2 columns]

# %%
df5=pd.read_csv("steam_reaview4.csv", header=0, usecols=["appid", "review"])
df5
# Out:
#          appid                                             review
# 0      1172470                                             guns\n
# 1      1172470   IF SOMEONE NAMED CRAN IS ON YOUR TEAM LEAVE H...
# 2      1172470  getting an account deactivated over a midly of...
# 3      1172470                                                  😊
# 4      1172470                                        good game\n
# ...        ...                                                ...
# 99995   271590            GUESS WHAT ? ITS NOW FREE ON EPIC GAMES
# 99996   271590      Green Gank is better Groove Stree 4 Life baby
# 99997   271590                                 ITS A GOOD GAME \n
# 99998   271590                                       Excelente :)
# 99999   271590                                               Best
#
# [100000 rows x 2 columns]

# %%
df6=pd.read_csv("steam_reaview5.csv", header=0, usecols=["appid", "review"])
df6
# Out:
#      appid                                             review
# 0   359550                               i GOT FALSELY BANNED
# 1   359550  Ubisoft just couldnt find my old account. I cr...
# 2   359550  i cant get it to load up at all anymore it was...
# 3   359550  The game needs some improvement certainly but ...
# 4   359550  Very laggy game, lots of lag-comp issues. Play...
# ..     ...                                                ...
# 91  359550  fking bugs and fps drop everytime also potato ...
# 92  359550  I enjoyed playing this game until I experience...
# 93  359550  This game fucking sucks i bought it and got no...
# 94  359550  Connection Failure:\nAbandonment Penalty\n...\...
# 95  359550                                            not bad
#
# [96 rows x 2 columns]

# %%
df7=pd.read_csv("steam_reaview6.csv", header=0, usecols=["appid", "review"])
df7
# Out:
#      appid                                             review
# 0   359550                               i GOT FALSELY BANNED
# 1   359550  Ubisoft just couldnt find my old account. I cr...
# 2   359550  i cant get it to load up at all anymore it was...
# 3   359550  The game needs some improvement certainly but ...
# 4   359550  Very laggy game, lots of lag-comp issues. Play...
# ..     ...                                                ...
# 91  359550  fking bugs and fps drop everytime also potato ...
# 92  359550  I enjoyed playing this game until I experience...
# 93  359550  This game fucking sucks i bought it and got no...
# 94  359550  Connection Failure:\nAbandonment Penalty\n...\...
# 95  359550                                            not bad
#
# [96 rows x 2 columns]

# %%
df8=pd.read_csv("steam_reaview7.csv", header=0, usecols=["appid", "review"])
df8
# Out:
#       appid                                             review
# 0    359550                               i GOT FALSELY BANNED
# 1    359550  Ubisoft just couldnt find my old account. I cr...
# 2    359550  i cant get it to load up at all anymore it was...
# 3    359550  The game needs some improvement certainly but ...
# 4    359550  Very laggy game, lots of lag-comp issues. Play...
# ..      ...                                                ...
# 187  359550  fking bugs and fps drop everytime also potato ...
# 188  359550  I enjoyed playing this game until I experience...
# 189  359550  This game fucking sucks i bought it and got no...
# 190  359550  Connection Failure:\nAbandonment Penalty\n...\...
# 191  359550                                            not bad
#
# [192 rows x 2 columns]

# %%
df9=pd.read_csv("steam_reaview8.csv", header=0, usecols=["appid", "review"])
df9
# Out:
#      appid                                             review
# 0   359550                               i GOT FALSELY BANNED
# 1   359550  Ubisoft just couldnt find my old account. I cr...
# 2   359550  i cant get it to load up at all anymore it was...
# 3   359550  The game needs some improvement certainly but ...
# 4   359550  Very laggy game, lots of lag-comp issues. Play...
# ..     ...                                                ...
# 91  359550  fking bugs and fps drop everytime also potato ...
# 92  359550  I enjoyed playing this game until I experience...
# 93  359550  This game fucking sucks i bought it and got no...
# 94  359550  Connection Failure:\nAbandonment Penalty\n...\...
# 95  359550                                            not bad
#
# [96 rows x 2 columns]

# %%
df10=pd.read_csv("steam_reaview9.csv", header=0, usecols=["appid", "review"])
df10
# Out:
#      appid                                             review
# 0   359550                               i GOT FALSELY BANNED
# 1   359550  Ubisoft just couldnt find my old account. I cr...
# 2   359550  i cant get it to load up at all anymore it was...
# 3   359550  The game needs some improvement certainly but ...
# 4   359550  Very laggy game, lots of lag-comp issues. Play...
# ..     ...                                                ...
# 91  359550  fking bugs and fps drop everytime also potato ...
# 92  359550  I enjoyed playing this game until I experience...
# 93  359550  This game fucking sucks i bought it and got no...
# 94  359550  Connection Failure:\nAbandonment Penalty\n...\...
# 95  359550                                            not bad
#
# [96 rows x 2 columns]

# %%
df11=pd.read_csv("steam_reaview10.csv", header=0, usecols=["appid", "review"])
df11
# Out:
#      appid                                             review
# 0   413150  I lost my save file once and got mad and wrote...
# 1   359550                               i GOT FALSELY BANNED
# 2   359550  Ubisoft just couldnt find my old account. I cr...
# 3   359550  i cant get it to load up at all anymore it was...
# 4   359550  The game needs some improvement certainly but ...
# ..     ...                                                ...
# 92  359550  fking bugs and fps drop everytime also potato ...
# 93  359550  I enjoyed playing this game until I experience...
# 94  359550  This game fucking sucks i bought it and got no...
# 95  359550  Connection Failure:\nAbandonment Penalty\n...\...
# 96  359550                                            not bad
#
# [97 rows x 2 columns]

# %%
df = pd.concat([df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], axis=0)
df
# Out:
#       appid                                             review
# 0   1446780  I've been playing for 3 Hours and its already ...
# 1   1446780                  I LOVE KILLING ENDANGERED SPECIES
# 2   1446780  I like to brutally murder animal species for a...
# 3   1446780  You can put cats into submarines to get honey ...
# 4   1446780                                         No handler
# ..      ...                                                ...
# 92   359550  fking bugs and fps drop everytime also potato ...
# 93   359550  I enjoyed playing this game until I experience...
# 94   359550  This game fucking sucks i bought it and got no...
# 95   359550  Connection Failure:\nAbandonment Penalty\n...\...
# 96   359550                                            not bad
#
# [400673 rows x 2 columns]

# %%
df = df.dropna()
df
# Out:
#       appid                                             review
# 0   1446780  I've been playing for 3 Hours and its already ...
# 1   1446780                  I LOVE KILLING ENDANGERED SPECIES
# 2   1446780  I like to brutally murder animal species for a...
# 3   1446780  You can put cats into submarines to get honey ...
# 4   1446780                                         No handler
# ..      ...                                                ...
# 92   359550  fking bugs and fps drop everytime also potato ...
# 93   359550  I enjoyed playing this game until I experience...
# 94   359550  This game fucking sucks i bought it and got no...
# 95   359550  Connection Failure:\nAbandonment Penalty\n...\...
# 96   359550                                            not bad
#
# [398964 rows x 2 columns]

# %%
s_df = pd.DataFrame(df['appid'].unique(), columns=['game'])
s_df.head()
# Out:
#       game
# 0  1446780
# 1  1172470
# 2   648800
# 3  1174180
# 4  1446780

# %%
s_df = pd.DataFrame(df['appid'].unique(), columns=['game'])
s_df.head()
# Out:
#       game
# 0  1446780
# 1  1172470
# 2   648800
# 3  1174180
# 4  1446780

# %%
for appid in df['appid'].unique():
  s_df.loc[s_df['game']==appid, 'review'] = " ".join(df[df['appid']==appid]['review'])

# %%
s_df
# Out:
#        game                                             review
# 0   1446780  I've been playing for 3 Hours and its already ...
# 1   1172470  guns\n  IF SOMEONE NAMED CRAN IS ON YOUR TEAM ...
# 2    648800  fun god\n assasasasa epik game lul good good M...
# 3   1174180  Just perfect in every way great game! Yes omg ...
# 4   1446780  I've been playing for 3 Hours and its already ...
# 5   1172470  guns\n  IF SOMEONE NAMED CRAN IS ON YOUR TEAM ...
# 6    648800  fun god\n assasasasa epik game lul good good M...
# 7   1174180  Just perfect in every way great game! Yes omg ...
# 8    578080  Game is so sick Game went doodoo for a while, ...
# 9   1222670  The holodeck has never been nicer!  Great esca...
# 10   271590  chutei um tryhard it's good cars, planes, and ...
# 11   359550  i GOT FALSELY BANNED Ubisoft just couldnt find...
# 12   413150  I lost my save file once and got mad and wrote...

# %%
s_df.rename(columns = {'game':'appid'},inplace=True)

# %%
df = pd.merge(df1, s_df, on='appid', how = 'left')
df
# Out:
#          appid                                              genre  \
# 0      1446780                                             Action
# 1      1172470                    Action, Adventure, Free to Play
# 2       648800                       Adventure, Indie, Simulation
# 3      1880360                                             Action
# 4       578080  Action, Adventure, Free to Play, Massively Mul...
# ...        ...                                                ...
# 63961  1204780                              Action, Casual, Indie
# 63962  1204820                                      Action, Indie
# 63963  1204830                              Action, Casual, Indie
# 63964  1190690                                        Action, RPG
# 63965  1190730                                  RPG, Early Access
#
#                                                   review
# 0      I've been playing for 3 Hours and its already ...
# 1      guns\n  IF SOMEONE NAMED CRAN IS ON YOUR TEAM ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63966 entries, 0 to 63965
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   appid   63966 non-null  object
#  1   genre   63966 non-null  object
#  2   review  8 non-null      object
# dtypes: object(3)
# memory usage: 2.0+ MB

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   appid   13 non-null     object
#  1   review  13 non-null     object
# dtypes: object(2)
# memory usage: 336.0+ bytes

# %%
df=df.dropna()
df
# Out:
#       appid                                              genre  \
# 0   1446780                                             Action
# 1   1172470                    Action, Adventure, Free to Play
# 2    648800                       Adventure, Indie, Simulation
# 4    578080  Action, Adventure, Free to Play, Massively Mul...
# 5   1174180                                  Action, Adventure
# 9   1222670                                 Casual, Simulation
# 12   359550                                             Action
# 15   413150                             Indie, RPG, Simulation
#
#                                                review
# 0   I've been playing for 3 Hours and its already ...
# 1   guns\n  IF SOMEONE NAMED CRAN IS ON YOUR TEAM ...
# 2   fun god\n assasasasa epik game lul good good M...
# 4   Game is so sick Game went doodoo for a while, ...
# 5   Just perfect in every way great game! Yes omg ...
# 9   The holodeck has never been nicer!  Great esca...
# ...

# %%
mask = df ['genre'] == 'Action'
df = df[mask]
df
# Out:
#       appid   genre                                             review
# 0   1446780  Action  I've been playing for 3 Hours and its already ...
# 12   359550  Action  i GOT FALSELY BANNED Ubisoft just couldnt find...

# %%
s_df = pd.DataFrame(df['genre'].unique(), columns=['genre'])
s_df.head()
# Out:
#     genre
# 0  Action

# %%
for genre in df['genre'].unique():
  s_df.loc[s_df['genre']==genre, 'review'] = " ".join(df[df['genre']==genre]['review'])

# %%
s_df.to_csv("action.csv")

# %%
s_df['review']
# Out:
# 0    I've been playing for 3 Hours and its already ...
# Name: review, dtype: object

# %%
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
# 전처리

# 영어, 숫자만 빼고 제거
def remain_engnum(sentence):
  sentence = re.sub('[^a-zA-Z0-9]+', ' ', sentence)
  return sentence

tqdm.pandas()
s_df['review'] = s_df['review'].progress_apply(lambda x:remain_engnum(x))

# 소문자화
s_df['review']= s_df['review'].apply(lambda x: x.lower())

vocab_size = 84617 # 단어사전 크기
total_tokenizer = Tokenizer(num_words = vocab_size) # 단어사전 생성
total_tokenizer.fit_on_texts(s_df['review']) # 학습

# 단어사전에서 인덱스가 84617 초과인 단어 제거
words_frequency = [word for word, index in total_tokenizer.word_index.items() if index >= vocab_size + 1]
for word in words_frequency:
    del total_tokenizer.word_index[word] # 해당 단어에 대한 인덱스 정보를 삭제
    del total_tokenizer.word_counts[word] # 해당 단어에 대한 카운트 정보를 삭제

# 토큰화
s_df['review'] = s_df['review'].progress_apply(lambda x:text_to_word_sequence(x))

# 희귀단어 제거
def remain_word(review):
  result = []
  for word in review:
    if word in total_tokenizer.word_index.keys():
      result.append(word)
  return result

s_df['review'] = s_df['review'].progress_apply(lambda x:remain_word(x))

# 불용어 제거
stop_words = set(stopwords.words('english'))

def remove_stopwords(text): 
    output= [i for i in text if i not in stop_words] 
    return output

s_df['review'] = s_df['review'].progress_apply(lambda x:remove_stopwords(x))

s_df
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.95it/s]
#     genre                                             review
# 0  Action  [playing, 3, hours, already, 16, hours, love, ...

# %%
s_df.to_csv("action.csv")

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   1 non-null      object
#  1   review  1 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes

# %%
s_df['review'][0]
# Out:
# ['playing',
#  '3',
#  'hours',
#  'already',
#  '16',
#  'hours',
#  'love',
#  'killing',
#  'endangered',
#  'species',
#  'like',
#  'brutally',
#  'murder',
#  'animal',
#  'species',
#  'cool',
#  'hat',
#  'put',
#  'cats',
#  'submarines',
#  'get',
#  'honey',
#  'handler',
#  'review',
#  'written',
#  'village',
#  'hub',
#  'urgent',
#  'quests',
#  'completed',
#  'monster',
#  'hunter',
#  'longer',
#  'tank',
#  'runs',
#  'breath',
#  'every',
#  '10',
#  'steps',
#  'instead',
#  'speed',
#  'versatility',
#  'dramatically',
#  'different',
#  'previous',
#  'titles',
#  'series',
#  'h1',
#  'b',
#  'good',
#  'stuff',
#  'b',
#  'h1',
#  'looking',
#  'monster',
#  'hunter',
#  'game',
#  'played',
#  'co',
#  'op',
#  'get',
#  'go',
#  'hit',
#  'jackpot',
#  'aside',
#  'couple',
#  'urgent',
#  'village',
#  'quests',
#  'game',
#  'resides',
#  'hub',
#  'area',
#  'available',
#  'right',
#  'start',
#  'asinine',
#  'quest',
#  'join',
#  'restrictions',
# ...

# %%
words = sum(s_df['review'], [])
words
# Out:
# ['playing',
#  '3',
#  'hours',
#  'already',
#  '16',
#  'hours',
#  'love',
#  'killing',
#  'endangered',
#  'species',
#  'like',
#  'brutally',
#  'murder',
#  'animal',
#  'species',
#  'cool',
#  'hat',
#  'put',
#  'cats',
#  'submarines',
#  'get',
#  'honey',
#  'handler',
#  'review',
#  'written',
#  'village',
#  'hub',
#  'urgent',
#  'quests',
#  'completed',
#  'monster',
#  'hunter',
#  'longer',
#  'tank',
#  'runs',
#  'breath',
#  'every',
#  '10',
#  'steps',
#  'instead',
#  'speed',
#  'versatility',
#  'dramatically',
#  'different',
#  'previous',
#  'titles',
#  'series',
#  'h1',
#  'b',
#  'good',
#  'stuff',
#  'b',
#  'h1',
#  'looking',
#  'monster',
#  'hunter',
#  'game',
#  'played',
#  'co',
#  'op',
#  'get',
#  'go',
#  'hit',
#  'jackpot',
#  'aside',
#  'couple',
#  'urgent',
#  'village',
#  'quests',
#  'game',
#  'resides',
#  'hub',
#  'area',
#  'available',
#  'right',
#  'start',
#  'asinine',
#  'quest',
#  'join',
#  'restrictions',
# ...

# %%
from collections import Counter

count = Counter(words) # 배열 안쪽 원소들이 등장한 빈도
words_dict = dict(count)

print(words_dict)
# Out:
# {'playing': 4710, '3': 2034, 'hours': 5312, 'already': 1831, '16': 222, 'love': 4645, 'killing': 438, 'endangered': 66, 'species': 138, 'like': 17951, 'brutally': 12, 'murder': 78, 'animal': 162, 'cool': 1968, 'hat': 144, 'put': 1634, 'cats': 462, 'submarines': 30, 'get': 9636, 'honey': 48, 'handler': 732, 'review': 2070, 'written': 96, 'village': 1788, 'hub': 1284, 'urgent': 96, 'quests': 3444, 'completed': 180, 'monster': 32430, 'hunter': 22782, 'longer': 662, 'tank': 66, 'runs': 1218, 'breath': 150, 'every': 3717, '10': 6732, 'steps': 186, 'instead': 1790, 'speed': 438, 'versatility': 24, 'dramatically': 30, 'different': 2503, 'previous': 1806, 'titles': 1038, 'series': 5322, 'h1': 1152, 'b': 3168, 'good': 14737, 'stuff': 1434, 'looking': 1824, 'game': 55151, 'played': 5047, 'co': 594, 'op': 720, 'go': 3828, 'hit': 1797, 'jackpot': 12, 'aside': 330, 'couple': 408, 'resides': 18, 'area': 432, 'available': 510, 'right': 1873, 'start': 1808, 'asinine': 18, 'quest': 2730, 'join': 1003
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1916/3266101202.py in <module>
# ----> 1 from wordcloud import WordCloud
#
# ~\Desktop\박시현\개발\프로젝트3\wordcloud.py in <module>
#      12 from soynlp.tokenizer import LTokenizer
#      13 from collections import Counter
# ---> 14 from wordcloud import WordCloud
#
# ImportError: cannot import name 'WordCloud' from partially initialized module 'wordcloud' (most likely due to a circular import) (C:\Users\hajer\Desktop\박시현\개발\프로젝트3\wordcloud.py)
